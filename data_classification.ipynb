# %% [markdown]
# <a href="https://colab.research.google.com/github/kananmeena/MyCaptain_Ai_assignements/blob/main/data_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOGISTIC REGRESSION

# %%
import pandas as pd

# %%
pima = pd.read_csv('diabetes.csv')
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']

# %%
del pima

# %%
pima = pd.read_csv('diabetes.csv', header =0, names=Col_names)

# %%
pima.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
feature_cols = ['pregnant', 'glucose', 'bp', 'insulin', 'bmi', 'pedigree', 'age']

# %%
x = pima[feature_cols] # Question bank (mock test will be spillted from this)
y= pima.label #answer key

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=16)

# %%
x_train.head()
# Out:
#      pregnant  glucose  bp  insulin   bmi  pedigree  age
# 695         7      142  90      480  30.4     0.128   43
# 119         4       99  76       51  23.2     0.223   21
# 135         2      125  60      140  33.8     0.088   31
# 675         6      195  70        0  30.9     0.328   31
# 326         1      122  64      156  35.1     0.692   30

# %%
x_test.head()
# Out:
#      pregnant  glucose  bp  insulin   bmi  pedigree  age
# 515         3      163  70      105  31.6     0.268   28
# 462         8       74  70       49  35.3     0.705   39
# 55          1       73  50        0  23.0     0.248   21
# 684         5      136  82        0   0.0     0.640   69
# 383         1       90  62       59  25.1     1.268   25

# %%
len(x_train)
# Out:
# 576

# %%
len(x)
# Out:
# 768

# %%
len(x_test)
# Out:
# 192

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(random_state=16)

# %%
logreg.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=16)

# %%
from sklearn import metrics

# %%
y_pred = logreg.predict(x_test)

# %%
cnf = metrics.confusion_matrix(y_test, y_pred)

# %%
cnf
# Out:
# array([[115,  10],
#        [ 25,  42]])

# %%
[['True positive', 'False negative'],
 ['False negative', 'True negative']]
# Out:
# [['True positive', 'False negative'], ['False negative', 'True negative']]
